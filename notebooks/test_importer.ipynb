# %%
from biokb_brenda2.db.importer import BrendaImporter
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
import os.path

engine = create_engine("sqlite:///brenda.db")
Session = sessionmaker(engine)

# %%
bi = BrendaImporter(engine)
bi.recreate_tables()

# %%
path = os.path.join("test_data", "brenda_test.json")
bi.import_from_file(path)
# Out:
# 100%|██████████| 10/10 [00:09<00:00,  1.06it/s]
# 10
