# %%
from biokb_brenda2.db.manager import DbManager
from biokb_brenda2.db import models
from sqlalchemy import func, select
from sqlalchemy import create_engine
from biokb_brenda2.db.importer import DbImporter
from sqlalchemy import inspect

engine = create_engine("mysql+pymysql://biokb_user:biokb_passwd@localhost:3307/biokb")
dbm = DbManager(engine)
dbm.import_data(data_file_path="test_data/brenda_test.json")
# dbm.import_data()
# dbi = DbImporter(engine)
# dbi.update_chebi_ids_with_chebi()
