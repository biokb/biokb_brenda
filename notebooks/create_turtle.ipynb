# %% [markdown]
# # Create turtle files

# %%
from biokb_brenda2.rdf.turtle import TurtleCreator
from sqlalchemy import create_engine
from biokb_brenda2.db.models import NSPReaction

engine = create_engine("mysql+pymysql://biokb_user:biokb_passwd@localhost/biokb")

tc = TurtleCreator(engine)
tc.create_all_ttls()
