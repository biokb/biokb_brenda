# %%
# !uv pip install -r requirements.txt
# Out:
# Using Python 3.13.2 environment at: /home/ceb/workspace/github/biokb/biokb_brenda/.venv
# Resolved 5 packages in 266ms
# Installed 2 packages in 3ms
#  + eralchemy==1.6.0
#  + graphviz==0.21

# %%
from eralchemy import render_er
from biokb_brenda.db.models import Base
import os

# %% [markdown]
# # Create entity-relationship diagram

# %%
render_er(Base, os.path.join("..", "docs", "imgs", "erd_from_sqlalchemy.png"))

# %% [markdown]
# ![](../docs/imgs/erd_from_sqlalchemy.png)
